# %% [markdown]
# # Desafio 3.
#
# ### Grupo N° 5.B
#
#     Integrantes:
#                 Bardauil, Joaquín
#                 Marquez, Hector
#                 Neustadt, Alejandro
#                 Pero, Felipe

# %% [markdown]
# ## Obtención de los datos y librerías necesarias.

# %%
# Importamos las librerías que usaremos durante la limpieza:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import scipy.stats as sts
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
from IPython.display import display
from pandas import ExcelWriter
from pandas import ExcelFile
import datetime

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Limpiamos los datos

# %%
# %run Limpieza_Pippo.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558074 entries, 0 to 558073
# Data columns (total 32 columns):
# Unnamed: 0                     558074 non-null int64
# Id                             558074 non-null int64
# ProductId                      558074 non-null int64
# Quantity                       558074 non-null int64
# Name                           558074 non-null object
# RefId                          558074 non-null object
# Price                          558074 non-null float64
# ListPrice                      558074 non-null float64
# SellerSKU                      558074 non-null int64
# PromoName                      558074 non-null object
# GrossItemAmountDiscount        558074 non-null float64
# RawItemDiscount                558074 non-null float64
# ShippingDataId                 558074 non-null object
# OrderDate                      558074 non-null datetime64[ns]
# OrderId                        558074 non-null object
# ...

# %% [markdown]
# ## Lineas y tipos de productos Pippo

# %%
# Realizamos Clasificaciones de Productos
# %run Líneas_y_tipos_de_productos_Pippo.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452063 entries, 0 to 452062
# Data columns (total 34 columns):
# Id                             452063 non-null int64
# ProductId                      452063 non-null int64
# Quantity                       452063 non-null int64
# Name                           452063 non-null object
# Price                          452063 non-null float64
# ListPrice                      452063 non-null float64
# PromoName                      452063 non-null object
# GrossItemAmountDiscount        452063 non-null float64
# RawItemDiscount                452063 non-null float64
# OrderId                        452063 non-null object
# DocumentType                   452063 non-null object
# SelectedAddressComplement      119969 non-null object
# SelectedAddressNeighborhood    104535 non-null object
# SelectedAddressPostalCode      452057 non-null float64
# SelectedAddressReference       1084 non-null object
# ...

# %% [markdown]
# ## Analizamos los datos

# %%
# %run Análisis_Pippo.ipynb
# Out:
# C:\Users\hmarq\Anaconda3\envs\Pippo\lib\site-packages\pandas\core\strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# TOP 10 PROVINCIAS CON MAYOR DEMANDA
# State
# Buenos Aires    364418
# Santa Fé         40545
# Montevideo       20348
# Tucumán          13581
# Entre Ríos        8765
# Mendoza           7425
# Río Negro         6574
# Chubut            6338
# Chaco             5937
# Neuquén           5562
# Name: Quantity, dtype: int64
# TOP 5 productos más demandados en Buenos Aires
# Name
# Juego de Toalla y Toallón Línea Turbat Color Gris Claro    3184
# Almohada 1 Plaza Vellón Color Blanco                       2623
# Juego de Toalla y Toallón Línea Turbat Color Blanco        2220
# Almohada 1 Plaza Vellón Siliconado Color Blanco            1967
# Almohada 1 Plaza Espuma Microprocesada Color Blanco        1713
# Name: Quantity, dtype: int64
#
# ...

# %% [markdown]
# ## Grafos

# %%
# Preparamos los datos para la generación de grafos:
# %run Preparacion_grafo_Pippo.ipynb

# Generamos los grafos:
# %run Análisis_grafo_Pippo.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452063 entries, 0 to 452062
# Data columns (total 32 columns):
# Id                             452063 non-null int64
# ProductId                      452063 non-null int64
# Quantity                       452063 non-null int64
# Name                           452063 non-null object
# Price                          452063 non-null float64
# ListPrice                      452063 non-null float64
# PromoName                      452063 non-null object
# GrossItemAmountDiscount        452063 non-null float64
# RawItemDiscount                452063 non-null float64
# OrderId                        452063 non-null object
# DocumentType                   452063 non-null object
# SelectedAddressComplement      119969 non-null object
# SelectedAddressNeighborhood    104535 non-null object
# SelectedAddressPostalCode      452057 non-null float64
# SelectedAddressReference       1084 non-null object
# ...

# %% [markdown]
# ## Predicciones

# %%
# Se preparan los datos para predecir ventas por Valor, Unidades, algun producto en particular y Typo de Producto
# %run Preparando_predicciones_Pipppo.ipynb

# Usaremos predicciones a traves de redes neuronales simples, multivariates y embeddings

# Valor
# %run T1_-Value_-_Prueba_Predicción_de_Series_Temporales_con_Redes_Neuronales.ipynb
# %run T2_-Value_-_Prueba_Predicción_de_Series_Temporales_NN_-_Multivariate.ipynb
# %run T3_-Value_-_Prueba_Predicción_de_Series_Temporales_NN_-_Embeddings.ipynb

# Unidades
# %run T1_-Unidades_-_Prueba_Predicción_de_Series_Temporales_con_Redes_Neuronales.ipynb
# %run T2_-Unidades_-_Prueba_Predicción_de_Series_Temporales_NN_-_Multivariate.ipynb
# %run T3_-Unidades_-_Prueba_Predicción_de_Series_Temporales_NN_-_Embeddings.ipynb

# Producto (Id)
# %run T1_-Id_-_Prueba_Predicción_de_Series_Temporales_con_Redes_Neuronales.ipynb
# %run T2_-Id_-_Prueba_Predicción_de_Series_Temporales_NN_-_Multivariate.ipynb
# %run T3_-Id_-_Prueba_Predicción_de_Series_Temporales_NN_-_Embeddings.ipynb

# Producto (Typo)
# %run T1_-Typo_-_Prueba_Predicción_de_Series_Temporales_con_Redes_Neuronales.ipynb
# %run T2_-Typo_-_Prueba_Predicción_de_Series_Temporales_NN_-_Multivariate.ipynb
# %run T3_-Typo_-_Prueba_Predicción_de_Series_Temporales_NN_-_Embeddings.ipynb
# Out:
# Preparando_predicciones_Pipppo.ipynb:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   {
# C:\Users\hmarq\Anaconda3\envs\Pippo\lib\site-packages\pandas\core\frame.py:4097: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Using TensorFlow backend.
# 2018-04-04 00:00:00
# 2019-06-21 00:00:00
# 241
# 170
# WARNING: Logging before flag parsing goes to stderr.
# ...

# %% [markdown]
# ## Recomendaciones

# %%
# Usaremos Recomendaciones usando ID y Tipo de Producto, con predictores Surprise y Turicreate

# Recomendacion Surprice como con Peliculas
# %run Recomendacion_ID_peliculas_adaptado_a_Pippo.ipynb
# %run Recomendacion_Typo_peliculas_adaptado_a_Pippo.ipynb

# Recomendacion Surprice usada en clase
# %run Sistema_de_recomendacion_usado_en_clase_adaptado_ID.ipynb
# %run Sistema_de_recomendacion_usado_en_clase_adaptado_Typo_Producto.ipynb

# Recomendacion Turicreate (a traves del Google Colab, chequeando que este cargado el Turicreate)
#%run Turicreate Recomendaciones para Tienda Pippo Id.ipynb
#%run Turicreate Recomendaciones para Tienda Pippo Typo.ipynb

# Recomendacion Didactica sobre los ultimos meses de trabajo tienda Pippo
# %run Recommendation_Engine_System_-_Didactico_ Pippo.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558074 entries, 0 to 558073
# Data columns (total 32 columns):
# Unnamed: 0                     558074 non-null int64
# Id                             558074 non-null int64
# ProductId                      558074 non-null int64
# Quantity                       558074 non-null int64
# Name                           558074 non-null object
# RefId                          558074 non-null object
# Price                          558074 non-null float64
# ListPrice                      558074 non-null float64
# SellerSKU                      558074 non-null int64
# PromoName                      558074 non-null object
# GrossItemAmountDiscount        558074 non-null float64
# RawItemDiscount                558074 non-null float64
# ShippingDataId                 558074 non-null object
# OrderDate                      558074 non-null datetime64[ns]
# OrderId                        558074 non-null object
# ...
